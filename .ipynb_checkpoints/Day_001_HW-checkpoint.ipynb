# %% [markdown]
# ## 作業1：
# ### 資料選擇：Chronic illness: symptoms, treatments and triggers
# ### 資料連結：https://www.kaggle.com/flaredown/flaredown-autoimmune-symptom-tracker#fd-export.csv
# #### 1. 你選的這組資料為何重要：
#     這筆資料為《Flaredown》app中的使用者資料共300多萬筆，裡面記錄
#     使用者“覺得”自己哪些疾病需要被記錄、目前應對的治療方法、心情等
#     等等，意味著這筆資料能提供全球人口在不同年齡層的健康程度，以及
#     「在什麼年齡層，最可能得到哪些疾病」，對於世界人口的醫療會有許
#     多從病人角度中取得之身體狀況、甚至“得哪些病會有什麼樣的心情”，
#     幫助理解人體醫學、身體狀況與心理的密切關係。
# #### 2. 資料從何而來 ：
#     Kaggle網站，《Flaredown》app
# #### 3. 蒐集而來的資料型態為何
#     已經是整理好的csv檔，可以直接匯入python處理的dataset，有數值、類別資料。
# #### 4. 這組資料想解決的問題如何評估
#     可以使用分類問題進行，把資料分類成不同的群體，因此需要AUC評估，此外ROC、
#     Sensitivity、Specificity同時也是此方法較為客觀之判準。

# %% [markdown]
# ## 作業2：
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     目標在於『提升業績』，因此直覺上“找出哪些地方淺在客源居多”會是首要目標，而簡單設不同時段在不同地段之客群數量不同（如某地段中午較多人），進一步延伸假設：地段客群數量是否隨都市機能而有不同？可針對地段分出「商業區地段客群」、「休閒區地段客群」、「觀光區地段客群」等等，而這些區段分別在白天、晚上、假日達到尖峰人潮，因此有了這些些類別，將所得取之地段資料進行分類，便能將車隊在特定時段集中到特定地點等待人潮。
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     政府公開資料、交通部資料（包含車流量地段、計程車數等等）、商業店家數量、地圖，利用上述資料組合可以解決問題，得出地段分區。
# #### 3. 蒐集而來的資料型態為何
#     政府公開資料、交通部資料、商業店家數量為已經整理好之dataset，有數值、類別資料，為csv或xlsx檔，能直接使用；地圖則為shp檔，應為地理坐標資料組成。
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     地段的分類效果能使用AUC、以及ROC、Sensitivity、Specificity與政府公開之都市計畫分區進行驗證比對。

# %% [markdown]
# ## 作業3：練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 311.832
# The Mean absolute error is 14.108
